# %% [markdown]
# # Using Pandas to handle datasets

# %% [markdown]
# ## Reference

# %% [markdown]
# <ol>
#     <li> Imports</li>
#     <li> Reading Files</li>
#     <li> Viewing rows</li>
#     <li> Describing datasets</li>
#     <li> Basic aggregations </li>
#     <li> Selecting specific rows</li><ol>
#         <li>By Row Number</li>
#         <li>By Conditions/Filters</li></ol>
#     <li> GroupBy and Aggregation</li>
#     <li> Join </li>
# </ol>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
os.chdir(r'C:\Users\shyam.ravikumar\Documents\MSU Python Training\Columbus_2019_Jul\Session-2\Assignment\Assignment_Input_Data')

# %% [markdown]
# ## Reading files

# %%
dataset_input_combats = pd.read_csv("combats.csv")
dataset_input_pokemon = pd.read_csv("pokemon.csv")

# %% [markdown]
# THis is a text

# %% [markdown]
# ## Viewing the dataset

# %%
dataset_input_pokemon.head(30)
# Out:
#      #              Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur   Grass  Poison  45      49       49       65
# 1    2           Ivysaur   Grass  Poison  60      62       63       80
# 2    3          Venusaur   Grass  Poison  80      82       83      100
# 3    4     Mega Venusaur   Grass  Poison  80     100      123      122
# 4    5        Charmander    Fire     NaN  39      52       43       60
# 5    6        Charmeleon    Fire     NaN  58      64       58       80
# 6    7         Charizard    Fire  Flying  78      84       78      109
# 7    8  Mega Charizard X    Fire  Dragon  78     130      111      130
# 8    9  Mega Charizard Y    Fire  Flying  78     104       78      159
# 9   10          Squirtle   Water     NaN  44      48       65       50
# 10  11         Wartortle   Water     NaN  59      63       80       65
# 11  12         Blastoise   Water     NaN  79      83      100       85
# ...

# %%
dataset_input_pokemon.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
dataset_input_pokemon.sample(10)
# Out:
#        #       Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 53    54    Venonat       Bug  Poison   60      55       50       40       55
# 142  143     Lapras     Water     Ice  130      85       80       85       95
# 655  656  Alomomola     Water     NaN  165      75       80       40       45
# 767  768  Tyrantrum      Rock  Dragon   82     121      119       69       59
# 314  315    Nincada       Bug  Ground   31      45       90       30       30
# 598  599      Throh  Fighting     NaN  120     100       85       30       85
# 442  443   Staravia    Normal  Flying   55      75       50       40       40
# 72    73     Machop  Fighting     NaN   70      80       50       35       35
# 658  659  Ferroseed     Grass   Steel   44      50       91       24       86
# 51    52      Paras       Bug   Grass   35      70       55       45       55
#
#      Speed  Generation  Legendary
# 53      45           1      False
# 142     60           1      False
# ...

# %% [markdown]
# ## Describe the dataset

# %%
dataset_input_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
dataset_input_pokemon.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
dataset_input_pokemon[['Name','Type 1']].head()
# Out:
#             Name Type 1
# 0      Bulbasaur  Grass
# 1        Ivysaur  Grass
# 2       Venusaur  Grass
# 3  Mega Venusaur  Grass
# 4     Charmander   Fire

# %%
dataset_input_pokemon.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
dataset_input_pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
dataset_input_pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# ## Basic Aggregations

# %%
my_data = dataset_input_pokemon['HP']
my_data.head()
# Out:
# 0    45
# 1    60
# 2    80
# 3    80
# 4    39
# Name: HP, dtype: int64

# %%
my_data.mean()
# Out:
# 69.25875

# %%
my_data.sum()
# Out:
# 55407

# %%
# %matplotlib inline

# %%
my_data.hist()

# %% [markdown]
# ## Selecting Rows

# %% [markdown]
# ### By position

# %%
dataset_input_pokemon.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# ### By condition

# %%
my_data = dataset_input_pokemon['Type 1']

# %%
my_data.head()
# Out:
# 0    Grass
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# Name: Type 1, dtype: object

# %%
is_grass = my_data=='Grass'

# %%
type(is_grass)
# Out:
# pandas.core.series.Series

# %%
dataset_input_pokemon[(dataset_input_pokemon['Type 1']=='Grass') & (dataset_input_pokemon['Generation']==5)]
# Out:
#        #        Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 554  555       Snivy  Grass       NaN   45      45       55       45       55
# 555  556     Servine  Grass       NaN   60      60       75       60       75
# 556  557   Serperior  Grass       NaN   75      75       95       75       95
# 570  571     Pansage  Grass       NaN   50      53       48       53       48
# 571  572    Simisage  Grass       NaN   75      98       63       98       63
# 606  607    Cottonee  Grass     Fairy   40      27       60       37       50
# 607  608  Whimsicott  Grass     Fairy   60      67       85       77       75
# 608  609     Petilil  Grass       NaN   45      35       50       70       50
# 609  610   Lilligant  Grass       NaN   70      60       75      110       75
# 617  618    Maractus  Grass       NaN   75      86       67      106       67
# 651  652     Foongus  Grass    Poison   69      55       45       55       55
# ...

# %%
data[is_grass]
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 3     80           1      False

# %% [markdown]
# ## Groupby

# %%
dataset_input_pokemon.groupby('Type 1')[['HP','Attack']].mean().head()
# Out:
#                  HP      Attack
# Type 1
# Bug       56.884058   70.971014
# Dark      66.806452   88.387097
# Dragon    83.312500  112.125000
# Electric  59.795455   69.090909
# Fairy     74.117647   61.529412

# %%
dataset_input_pokemon.groupby('Type 1')['Attack'].sum().sum()
# Out:
# 63201

# %% [markdown]
# ## Joining/Merging

# %%
dataset_input_combats.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
dataset_input_pokemon.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
table_a = dataset_input_pokemon[['#','Name']]
table_b = dataset_input_combats

# %%
table_a.head()
# Out:
#    #           Name
# 0  1      Bulbasaur
# 1  2        Ivysaur
# 2  3       Venusaur
# 3  4  Mega Venusaur
# 4  5     Charmander

# %%
result = table_a.merge(table_b,how='right',left_on='#',right_on='First_pokemon')

# %%
result.sample(10)
# Out:
#          #                   Name  First_pokemon  Second_pokemon  Winner
# 34229  546  Giratina Origin Forme            546             475     475
# 29887  477           Mega Lopunny            477             176     477
# 23758  380                Anorith            380             737     737
# 37606  599                  Throh            599             402     599
# 5674    95                Dewgong             95             212     212
# 34976  559                Pignite            559             506     559
# 29224  466                 Buizel            466             611     611
# 16324  263                 Raikou            263             593     263
# 7933   130                 Staryu            130              51      51
# 17409  281                 Mudkip            281             790     281

# %%
dataset_input_pokemon.shape
# Out:
# (800, 12)

# %%
dataset_input_combats.shape
# Out:
# (50000, 3)

# %%
result.shape
# Out:
# (50000, 5)

# %% [markdown]
# Table A: A,B,C
#
# Table B: A,X,Y
#
# Table C: A,B,C,X,Y

# %% [markdown]
# Table A: A,B,C,X
#
# Table B: A,X,Y
#
# Table C:
